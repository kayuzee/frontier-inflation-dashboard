# %%
import quandl
import numpy as np
import pandas as pd
quandl.ApiConfig.api_key = "YOUR_API_KEY_HERE" #Enter Your Quandl API Key here
from bokeh.plotting import figure, output_file, show
from bokeh.io import gridplot, output_file, show, gridplot

# %%
 msci = ['Argentina','Bahrain','Bangladesh', 'Bulgaria','Croatia', 'Estonia', 'Jordan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Lebanon',
 'Lithuania','Mauritius','Morocco','Nigeria','Oman','Pakistan','Romania','Serbia', 'Slovenia','Sri Lanka','Trinidad and Tobago',
 'Tunisia','Ukraine', 'Vietnam',]
 
 qcodes = ['ARG', 'BHR', 'BGD', 'BGR', 'HRV', 'EST', 'JOR', 'KAZ', 'KEN', 'KWT', 'LBN', 'LTU', 'MUS', 'MAR', 'NGA', 
 'OMN', 'PAK', 'ROU', 'SRB', 'SVN', 'LKA', 'TTO', 'TUN', 'UKR', 'VNM']
 len(qcodes)
# Out:
# 25

# %%
#script to generate quandl api codes
msci[0] = quandl.get('ODA/'+qcodes[0]+'_PCPI') 
msci[1] = quandl.get('ODA/'+qcodes[1]+'_PCPI') 
msci[2] = quandl.get('ODA/'+qcodes[2]+'_PCPI')
msci[3] = quandl.get('ODA/'+qcodes[3]+'_PCPI')
msci[4] = quandl.get('ODA/'+qcodes[4]+'_PCPI')
msci[5] = quandl.get('ODA/'+qcodes[5]+'_PCPI')
msci[6] = quandl.get('ODA/'+qcodes[6]+'_PCPI')
msci[7] = quandl.get('ODA/'+qcodes[7]+'_PCPI')
msci[8] = quandl.get('ODA/'+qcodes[8]+'_PCPI')
msci[9] = quandl.get('ODA/'+qcodes[9]+'_PCPI')
msci[10] = quandl.get('ODA/'+qcodes[10]+'_PCPI')
msci[11] = quandl.get('ODA/'+qcodes[11]+'_PCPI')
msci[12] = quandl.get('ODA/'+qcodes[12]+'_PCPI')
msci[13] = quandl.get('ODA/'+qcodes[13]+'_PCPI')
msci[14] = quandl.get('ODA/'+qcodes[14]+'_PCPI')
msci[15] = quandl.get('ODA/'+qcodes[15]+'_PCPI')
msci[16] = quandl.get('ODA/'+qcodes[16]+'_PCPI')
msci[17] = quandl.get('ODA/'+qcodes[17]+'_PCPI')
msci[18] = quandl.get('ODA/'+qcodes[18]+'_PCPI')
msci[19] = quandl.get('ODA/'+qcodes[19]+'_PCPI')
msci[20] = quandl.get('ODA/'+qcodes[20]+'_PCPI')
msci[21] = quandl.get('ODA/'+qcodes[21]+'_PCPI')
msci[22] = quandl.get('ODA/'+qcodes[22]+'_PCPI')
msci[23] = quandl.get('ODA/'+qcodes[23]+'_PCPI')
msci[24] = quandl.get('ODA/'+qcodes[24]+'_PCPI')

# %% [markdown]
# msci = ['Argentina','Bahrain','Bangladesh', 'Bulgaria','Croatia', 'Estonia', 'Jordan', 'Kazakhstan', 'Kenya', 'Kuwait', 'Lebanon',
#  'Lithuania','Mauritius','Morocco','Nigeria','Oman','Pakistan','Romania','Serbia', 'Slovenia','Sri Lanka','Trinidad and Tobago',
#  'Tunisia','Ukraine', 'Vietnam']

# %%
argentina_inflation = msci[0] 
argentina_inflation['Date'] = argentina_inflation.index

bahrain_inflation = msci[1]
bahrain_inflation['Date'] = bahrain_inflation.index

bangladesh_inflation = msci[2]
bangladesh_inflation['Date'] = bangladesh_inflation.index

bulgaria_inflation = msci[3]
bulgaria_inflation['Date'] = bulgaria_inflation.index

croatia_inflation = msci[4]
croatia_inflation['Date'] = croatia_inflation.index

estonia_inflation = msci[5]
estonia_inflation['Date'] = estonia_inflation.index

jordan_inflation = msci[6]
jordan_inflation['Date'] = jordan_inflation.index

kazakhstan_inflation = msci[7]
kazakhstan_inflation['Date'] = kazakhstan_inflation.index

kenya_inflation = msci[8]
kenya_inflation['Date'] = kenya_inflation.index

kuwait_inflation = msci[9]
kuwait_inflation['Date'] = kuwait_inflation.index

# %%
output_file("frontier_inflation.html")
g0 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Argentina Inflation 1985- ')
g1 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Bahrain Inflation 1980- ')
g2 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Bangladesh Inflation 1980- ')
g3 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Bulgaria Inflation 1980- ')
g4 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Croatia Inflation 1994- ')
g5 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Estonia Inflation 1994- ')
g6 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Jordan Inflation 1980- ')
g7 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Kazakhstan Inflation 1994- ')
g8 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Kenya Inflation 1980- ')
g9 = figure(plot_width=300, plot_height=300, x_axis_type="datetime", title ='Kuwait Inflation 1980- ')

# add a line renderer
g0.line(argentina_inflation['Date'], argentina_inflation['Value'], line_width=2)
g1.line(bahrain_inflation['Date'], bahrain_inflation['Value'], line_width=2)
g2.line(bangladesh_inflation['Date'], bangladesh_inflation['Value'], line_width=2)
g3.line(bulgaria_inflation['Date'], bulgaria_inflation['Value'], line_width=2)
g4.line(croatia_inflation['Date'], croatia_inflation['Value'], line_width=2)
g5.line(estonia_inflation['Date'], estonia_inflation['Value'], line_width=2)
g6.line(jordan_inflation['Date'], jordan_inflation['Value'], line_width=2)
g7.line(kazakhstan_inflation['Date'], kazakhstan_inflation['Value'], line_width=2)
g8.line(kenya_inflation['Date'], kenya_inflation['Value'], line_width=2)
g9.line(kuwait_inflation['Date'], kuwait_inflation['Value'], line_width=2)

p = gridplot([[g0, g1, g2, g3, g4],[g5, g6, g7, g8, g9]])

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1251a58f-6fcd-485d-bd7e-72f7151fc36e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
